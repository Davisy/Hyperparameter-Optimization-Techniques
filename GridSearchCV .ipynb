# %% [markdown]
# ### HYPERPARAMETER OPTIMIZATION WITH GRIDSERCHCV

# %%
# import packages 
import numpy as np 
import pandas as pd 
from sklearn.ensemble import RandomForestClassifier 
from sklearn import metrics 
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler 

import warnings
warnings.filterwarnings("ignore")

# %%
# load data 
data = pd.read_csv("data/mobile_price_data.csv")

# %%
#read data 
data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
#
# [5 rows x 21 columns]

# %%
#show shape
data.shape
# Out:
# (2000, 21)

# %%
#show list of columns 
list(data.columns)
# Out:
# ['battery_power',
#  'blue',
#  'clock_speed',
#  'dual_sim',
#  'fc',
#  'four_g',
#  'int_memory',
#  'm_dep',
#  'mobile_wt',
#  'n_cores',
#  'pc',
#  'px_height',
#  'px_width',
#  'ram',
#  'sc_h',
#  'sc_w',
#  'talk_time',
#  'three_g',
#  'touch_screen',
#  'wifi',
#  'price_range']

# %%
# show data properties
data.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# min       0.000000     2.000000     0.100000    80.000000     1.000000  ...
# 25%       0.000000    16.000000     0.200000   109.000000     3.000000  ...
# 50%       1.000000    32.000000     0.500000   141.000000     4.000000  ...
# 75%       1.000000    48.000000     0.800000   170.000000     7.000000  ...
# max       1.000000    64.000000     1.000000   200.000000     8.000000  ...
#
#          px_height     px_width          ram         sc_h         sc_w  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean    645.108000  1251.515500  2124.213000    12.306500     5.767000
# std     443.780811   432.199447  1084.732044     4.213245     4.356398
# min       0.000000   500.000000   256.000000     5.000000     0.000000
# 25%     282.750000   874.750000  1207.500000     9.000000     2.000000
# 50%     564.000000  1247.000000  2146.500000    12.000000     5.000000
# 75%     947.250000  1633.000000  3064.500000    16.000000     9.000000
# max    1960.000000  1998.000000  3998.000000    19.000000    18.000000
#
#          talk_time      three_g  touch_screen         wifi  price_range
# count  2000.000000  2000.000000   2000.000000  2000.000000  2000.000000
# mean     11.011000     0.761500      0.503000     0.507000     1.500000
# std       5.463955     0.426273      0.500116     0.500076     1.118314
# min       2.000000     0.000000      0.000000     0.000000     0.000000
# 25%       6.000000     1.000000      0.000000     0.000000     0.750000
# 50%      11.000000     1.000000      1.000000     1.000000     1.500000
# 75%      16.000000     1.000000      1.000000     1.000000     2.250000
# max      20.000000     1.000000      1.000000     1.000000     3.000000
#
# [8 rows x 21 columns]

# %%
# show data information 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
#  18  touch_screen   2000 non-null   int64
#  19  wifi           2000 non-null   int64
#  20  price_range    2000 non-null   int64
# dtypes: float64(2), int64(19)
# memory usage: 328.2 KB

# %%
# check if it has missing values 
data.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
# split data into features and target 
X = data.drop("price_range", axis=1).values 
y = data.price_range.values

# %%
# standardize the feature variables 
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
#Create classifier 
rf_classifier = RandomForestClassifier(n_jobs=-1)

# %%
# set different parameter values to tune
param_grid = {
    "n_estimators": [100, 200, 300, 400],
    "max_depth": [1, 3, 5, 7, 9],
    "criterion": ["gini", "entropy"],
}

# %%
# set gridsearch
model = GridSearchCV(
    estimator=rf_classifier, param_grid=param_grid, cv=5, verbose=2, n_jobs=1
)

# %%
# train the model with gridserchCV 
model.fit(X_scaled,y)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV] criterion=gini, max_depth=1, n_estimators=100 ...................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .... criterion=gini, max_depth=1, n_estimators=100, total=   5.2s
# [CV] criterion=gini, max_depth=1, n_estimators=100 ...................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    5.1s remaining:    0.0s
# [CV] .... criterion=gini, max_depth=1, n_estimators=100, total=   0.4s
# [CV] criterion=gini, max_depth=1, n_estimators=100 ...................
# [CV] .... criterion=gini, max_depth=1, n_estimators=100, total=   0.4s
# [CV] criterion=gini, max_depth=1, n_estimators=100 ...................
# [CV] .... criterion=gini, max_depth=1, n_estimators=100, total=   0.4s
# [CV] criterion=gini, max_depth=1, n_estimators=100 ...................
# [CV] .... criterion=gini, max_depth=1, n_estimators=100, total=   0.4s
# [CV] criterion=gini, max_depth=1, n_estimators=200 ...................
# [CV] .... criterion=gini, max_depth=1, n_estimators=200, total=   0.7s
# [CV] criterion=gini, max_depth=1, n_estimators=200 ...................
# [CV] .... criterion=gini, max_depth=1, n_estimators=200, total=   0.7s
# [CV] criterion=gini, max_depth=1, n_estimators=200 ...................
# [CV] .... criterion=gini, max_depth=1, n_estimators=200, total=   0.6s
# [CV] criterion=gini, max_depth=1, n_estimators=200 ...................
# [CV] .... criterion=gini, max_depth=1, n_estimators=200, total=   0.7s
# [CV] criterion=gini, max_depth=1, n_estimators=200 ...................
# [CV] .... criterion=gini, max_depth=1, n_estimators=200, total=   0.7s
# [CV] criterion=gini, max_depth=1, n_estimators=300 ...................
# [CV] .... criterion=gini, max_depth=1, n_estimators=300, total=   1.0s
# [CV] criterion=gini, max_depth=1, n_estimators=300 ...................
# [CV] .... criterion=gini, max_depth=1, n_estimators=300, total=   0.9s
# [CV] criterion=gini, max_depth=1, n_estimators=300 ...................
# [CV] .... criterion=gini, max_depth=1, n_estimators=300, total=   1.1s
# [CV] criterion=gini, max_depth=1, n_estimators=300 ...................
# [CV] .... criterion=gini, max_depth=1, n_estimators=300, total=   0.9s
# [CV] criterion=gini, max_depth=1, n_estimators=300 ...................
# [CV] .... criterion=gini, max_depth=1, n_estimators=300, total=   1.2s
# [CV] criterion=gini, max_depth=1, n_estimators=400 ...................
# [CV] .... criterion=gini, max_depth=1, n_estimators=400, total=   1.2s
# [CV] criterion=gini, max_depth=1, n_estimators=400 ...................
# [CV] .... criterion=gini, max_depth=1, n_estimators=400, total=   1.1s
# [CV] criterion=gini, max_depth=1, n_estimators=400 ...................
# [CV] .... criterion=gini, max_depth=1, n_estimators=400, total=   1.2s
# [CV] criterion=gini, max_depth=1, n_estimators=400 ...................
# [CV] .... criterion=gini, max_depth=1, n_estimators=400, total=   1.1s
# [CV] criterion=gini, max_depth=1, n_estimators=400 ...................
# [CV] .... criterion=gini, max_depth=1, n_estimators=400, total=   1.1s
# [CV] criterion=gini, max_depth=3, n_estimators=100 ...................
# [CV] .... criterion=gini, max_depth=3, n_estimators=100, total=   0.4s
# [CV] criterion=gini, max_depth=3, n_estimators=100 ...................
# [CV] .... criterion=gini, max_depth=3, n_estimators=100, total=   0.4s
# [CV] criterion=gini, max_depth=3, n_estimators=100 ...................
# [CV] .... criterion=gini, max_depth=3, n_estimators=100, total=   0.4s
# [CV] criterion=gini, max_depth=3, n_estimators=100 ...................
# [CV] .... criterion=gini, max_depth=3, n_estimators=100, total=   0.4s
# [CV] criterion=gini, max_depth=3, n_estimators=100 ...................
# [CV] .... criterion=gini, max_depth=3, n_estimators=100, total=   0.4s
# [CV] criterion=gini, max_depth=3, n_estimators=200 ...................
# [CV] .... criterion=gini, max_depth=3, n_estimators=200, total=   0.6s
# [CV] criterion=gini, max_depth=3, n_estimators=200 ...................
# [CV] .... criterion=gini, max_depth=3, n_estimators=200, total=   0.6s
# [CV] criterion=gini, max_depth=3, n_estimators=200 ...................
# [CV] .... criterion=gini, max_depth=3, n_estimators=200, total=   0.6s
# [CV] criterion=gini, max_depth=3, n_estimators=200 ...................
# [CV] .... criterion=gini, max_depth=3, n_estimators=200, total=   0.6s
# [CV] criterion=gini, max_depth=3, n_estimators=200 ...................
# [CV] .... criterion=gini, max_depth=3, n_estimators=200, total=   0.6s
# [CV] criterion=gini, max_depth=3, n_estimators=300 ...................
# [CV] .... criterion=gini, max_depth=3, n_estimators=300, total=   1.0s
# [CV] criterion=gini, max_depth=3, n_estimators=300 ...................
# [CV] .... criterion=gini, max_depth=3, n_estimators=300, total=   1.0s
# [CV] criterion=gini, max_depth=3, n_estimators=300 ...................
# [CV] .... criterion=gini, max_depth=3, n_estimators=300, total=   1.0s
# [CV] criterion=gini, max_depth=3, n_estimators=300 ...................
# [CV] .... criterion=gini, max_depth=3, n_estimators=300, total=   1.1s
# [CV] criterion=gini, max_depth=3, n_estimators=300 ...................
# [CV] .... criterion=gini, max_depth=3, n_estimators=300, total=   1.0s
# [CV] criterion=gini, max_depth=3, n_estimators=400 ...................
# [CV] .... criterion=gini, max_depth=3, n_estimators=400, total=   1.1s
# [CV] criterion=gini, max_depth=3, n_estimators=400 ...................
# [CV] .... criterion=gini, max_depth=3, n_estimators=400, total=   1.1s
# [CV] criterion=gini, max_depth=3, n_estimators=400 ...................
# [CV] .... criterion=gini, max_depth=3, n_estimators=400, total=   1.1s
# [CV] criterion=gini, max_depth=3, n_estimators=400 ...................
# [CV] .... criterion=gini, max_depth=3, n_estimators=400, total=   1.2s
# [CV] criterion=gini, max_depth=3, n_estimators=400 ...................
# [CV] .... criterion=gini, max_depth=3, n_estimators=400, total=   1.2s
# [CV] criterion=gini, max_depth=5, n_estimators=100 ...................
# [CV] .... criterion=gini, max_depth=5, n_estimators=100, total=   0.4s
# [CV] criterion=gini, max_depth=5, n_estimators=100 ...................
# [CV] .... criterion=gini, max_depth=5, n_estimators=100, total=   0.5s
# [CV] criterion=gini, max_depth=5, n_estimators=100 ...................
# [CV] .... criterion=gini, max_depth=5, n_estimators=100, total=   0.5s
# [CV] criterion=gini, max_depth=5, n_estimators=100 ...................
# [CV] .... criterion=gini, max_depth=5, n_estimators=100, total=   0.5s
# [CV] criterion=gini, max_depth=5, n_estimators=100 ...................
# [CV] .... criterion=gini, max_depth=5, n_estimators=100, total=   0.5s
# [CV] criterion=gini, max_depth=5, n_estimators=200 ...................
# [CV] .... criterion=gini, max_depth=5, n_estimators=200, total=   0.7s
# [CV] criterion=gini, max_depth=5, n_estimators=200 ...................
# [CV] .... criterion=gini, max_depth=5, n_estimators=200, total=   0.7s
# [CV] criterion=gini, max_depth=5, n_estimators=200 ...................
# [CV] .... criterion=gini, max_depth=5, n_estimators=200, total=   0.6s
# [CV] criterion=gini, max_depth=5, n_estimators=200 ...................
# [CV] .... criterion=gini, max_depth=5, n_estimators=200, total=   0.6s
# [CV] criterion=gini, max_depth=5, n_estimators=200 ...................
# [CV] .... criterion=gini, max_depth=5, n_estimators=200, total=   0.6s
# [CV] criterion=gini, max_depth=5, n_estimators=300 ...................
# [CV] .... criterion=gini, max_depth=5, n_estimators=300, total=   0.9s
# [CV] criterion=gini, max_depth=5, n_estimators=300 ...................
# [CV] .... criterion=gini, max_depth=5, n_estimators=300, total=   0.9s
# [CV] criterion=gini, max_depth=5, n_estimators=300 ...................
# [CV] .... criterion=gini, max_depth=5, n_estimators=300, total=   1.1s
# [CV] criterion=gini, max_depth=5, n_estimators=300 ...................
# [CV] .... criterion=gini, max_depth=5, n_estimators=300, total=   1.0s
# [CV] criterion=gini, max_depth=5, n_estimators=300 ...................
# [CV] .... criterion=gini, max_depth=5, n_estimators=300, total=   0.9s
# [CV] criterion=gini, max_depth=5, n_estimators=400 ...................
# [CV] .... criterion=gini, max_depth=5, n_estimators=400, total=   1.2s
# [CV] criterion=gini, max_depth=5, n_estimators=400 ...................
# [CV] .... criterion=gini, max_depth=5, n_estimators=400, total=   1.2s
# [CV] criterion=gini, max_depth=5, n_estimators=400 ...................
# [CV] .... criterion=gini, max_depth=5, n_estimators=400, total=   1.3s
# [CV] criterion=gini, max_depth=5, n_estimators=400 ...................
# [CV] .... criterion=gini, max_depth=5, n_estimators=400, total=   1.2s
# [CV] criterion=gini, max_depth=5, n_estimators=400 ...................
# [CV] .... criterion=gini, max_depth=5, n_estimators=400, total=   1.2s
# [CV] criterion=gini, max_depth=7, n_estimators=100 ...................
# [CV] .... criterion=gini, max_depth=7, n_estimators=100, total=   0.4s
# [CV] criterion=gini, max_depth=7, n_estimators=100 ...................
# [CV] .... criterion=gini, max_depth=7, n_estimators=100, total=   0.4s
# [CV] criterion=gini, max_depth=7, n_estimators=100 ...................
# [CV] .... criterion=gini, max_depth=7, n_estimators=100, total=   0.4s
# [CV] criterion=gini, max_depth=7, n_estimators=100 ...................
# [CV] .... criterion=gini, max_depth=7, n_estimators=100, total=   0.4s
# [CV] criterion=gini, max_depth=7, n_estimators=100 ...................
# [CV] .... criterion=gini, max_depth=7, n_estimators=100, total=   0.4s
# [CV] criterion=gini, max_depth=7, n_estimators=200 ...................
# [CV] .... criterion=gini, max_depth=7, n_estimators=200, total=   0.7s
# [CV] criterion=gini, max_depth=7, n_estimators=200 ...................
# [CV] .... criterion=gini, max_depth=7, n_estimators=200, total=   0.7s
# [CV] criterion=gini, max_depth=7, n_estimators=200 ...................
# [CV] .... criterion=gini, max_depth=7, n_estimators=200, total=   0.7s
# [CV] criterion=gini, max_depth=7, n_estimators=200 ...................
# [CV] .... criterion=gini, max_depth=7, n_estimators=200, total=   0.9s
# [CV] criterion=gini, max_depth=7, n_estimators=200 ...................
# [CV] .... criterion=gini, max_depth=7, n_estimators=200, total=   0.7s
# [CV] criterion=gini, max_depth=7, n_estimators=300 ...................
# [CV] .... criterion=gini, max_depth=7, n_estimators=300, total=   1.1s
# [CV] criterion=gini, max_depth=7, n_estimators=300 ...................
# [CV] .... criterion=gini, max_depth=7, n_estimators=300, total=   1.0s
# [CV] criterion=gini, max_depth=7, n_estimators=300 ...................
# [CV] .... criterion=gini, max_depth=7, n_estimators=300, total=   1.0s
# [CV] criterion=gini, max_depth=7, n_estimators=300 ...................
# [CV] .... criterion=gini, max_depth=7, n_estimators=300, total=   1.0s
# [CV] criterion=gini, max_depth=7, n_estimators=300 ...................
# [CV] .... criterion=gini, max_depth=7, n_estimators=300, total=   1.0s
# [CV] criterion=gini, max_depth=7, n_estimators=400 ...................
# [CV] .... criterion=gini, max_depth=7, n_estimators=400, total=   1.2s
# [CV] criterion=gini, max_depth=7, n_estimators=400 ...................
# [CV] .... criterion=gini, max_depth=7, n_estimators=400, total=   1.3s
# [CV] criterion=gini, max_depth=7, n_estimators=400 ...................
# [CV] .... criterion=gini, max_depth=7, n_estimators=400, total=   1.4s
# [CV] criterion=gini, max_depth=7, n_estimators=400 ...................
# [CV] .... criterion=gini, max_depth=7, n_estimators=400, total=   1.3s
# [CV] criterion=gini, max_depth=7, n_estimators=400 ...................
# [CV] .... criterion=gini, max_depth=7, n_estimators=400, total=   1.1s
# [CV] criterion=gini, max_depth=9, n_estimators=100 ...................
# [CV] .... criterion=gini, max_depth=9, n_estimators=100, total=   0.4s
# [CV] criterion=gini, max_depth=9, n_estimators=100 ...................
# [CV] .... criterion=gini, max_depth=9, n_estimators=100, total=   0.4s
# [CV] criterion=gini, max_depth=9, n_estimators=100 ...................
# [CV] .... criterion=gini, max_depth=9, n_estimators=100, total=   0.4s
# [CV] criterion=gini, max_depth=9, n_estimators=100 ...................
# [CV] .... criterion=gini, max_depth=9, n_estimators=100, total=   0.4s
# [CV] criterion=gini, max_depth=9, n_estimators=100 ...................
# [CV] .... criterion=gini, max_depth=9, n_estimators=100, total=   0.4s
# [CV] criterion=gini, max_depth=9, n_estimators=200 ...................
# [CV] .... criterion=gini, max_depth=9, n_estimators=200, total=   0.8s
# [CV] criterion=gini, max_depth=9, n_estimators=200 ...................
# [CV] .... criterion=gini, max_depth=9, n_estimators=200, total=   0.7s
# [CV] criterion=gini, max_depth=9, n_estimators=200 ...................
# [CV] .... criterion=gini, max_depth=9, n_estimators=200, total=   0.8s
# [CV] criterion=gini, max_depth=9, n_estimators=200 ...................
# [CV] .... criterion=gini, max_depth=9, n_estimators=200, total=   0.9s
# [CV] criterion=gini, max_depth=9, n_estimators=200 ...................
# [CV] .... criterion=gini, max_depth=9, n_estimators=200, total=   0.9s
# [CV] criterion=gini, max_depth=9, n_estimators=300 ...................
# [CV] .... criterion=gini, max_depth=9, n_estimators=300, total=   1.2s
# [CV] criterion=gini, max_depth=9, n_estimators=300 ...................
# [CV] .... criterion=gini, max_depth=9, n_estimators=300, total=   1.3s
# [CV] criterion=gini, max_depth=9, n_estimators=300 ...................
# [CV] .... criterion=gini, max_depth=9, n_estimators=300, total=   1.1s
# [CV] criterion=gini, max_depth=9, n_estimators=300 ...................
# [CV] .... criterion=gini, max_depth=9, n_estimators=300, total=   1.1s
# [CV] criterion=gini, max_depth=9, n_estimators=300 ...................
# [CV] .... criterion=gini, max_depth=9, n_estimators=300, total=   1.0s
# [CV] criterion=gini, max_depth=9, n_estimators=400 ...................
# [CV] .... criterion=gini, max_depth=9, n_estimators=400, total=   1.2s
# [CV] criterion=gini, max_depth=9, n_estimators=400 ...................
# [CV] .... criterion=gini, max_depth=9, n_estimators=400, total=   1.5s
# [CV] criterion=gini, max_depth=9, n_estimators=400 ...................
# [CV] .... criterion=gini, max_depth=9, n_estimators=400, total=   1.5s
# [CV] criterion=gini, max_depth=9, n_estimators=400 ...................
# [CV] .... criterion=gini, max_depth=9, n_estimators=400, total=   1.5s
# [CV] criterion=gini, max_depth=9, n_estimators=400 ...................
# [CV] .... criterion=gini, max_depth=9, n_estimators=400, total=   3.9s
# [CV] criterion=entropy, max_depth=1, n_estimators=100 ................
# [CV] . criterion=entropy, max_depth=1, n_estimators=100, total=   0.8s
# [CV] criterion=entropy, max_depth=1, n_estimators=100 ................
# [CV] . criterion=entropy, max_depth=1, n_estimators=100, total=   0.6s
# [CV] criterion=entropy, max_depth=1, n_estimators=100 ................
# [CV] . criterion=entropy, max_depth=1, n_estimators=100, total=   0.6s
# [CV] criterion=entropy, max_depth=1, n_estimators=100 ................
# [CV] . criterion=entropy, max_depth=1, n_estimators=100, total=   0.5s
# [CV] criterion=entropy, max_depth=1, n_estimators=100 ................
# [CV] . criterion=entropy, max_depth=1, n_estimators=100, total=   0.5s
# [CV] criterion=entropy, max_depth=1, n_estimators=200 ................
# [CV] . criterion=entropy, max_depth=1, n_estimators=200, total=   0.7s
# [CV] criterion=entropy, max_depth=1, n_estimators=200 ................
# [CV] . criterion=entropy, max_depth=1, n_estimators=200, total=   0.6s
# [CV] criterion=entropy, max_depth=1, n_estimators=200 ................
# [CV] . criterion=entropy, max_depth=1, n_estimators=200, total=   0.7s
# [CV] criterion=entropy, max_depth=1, n_estimators=200 ................
# [CV] . criterion=entropy, max_depth=1, n_estimators=200, total=   0.7s
# [CV] criterion=entropy, max_depth=1, n_estimators=200 ................
# [CV] . criterion=entropy, max_depth=1, n_estimators=200, total=   0.6s
# [CV] criterion=entropy, max_depth=1, n_estimators=300 ................
# [CV] . criterion=entropy, max_depth=1, n_estimators=300, total=   1.3s
# [CV] criterion=entropy, max_depth=1, n_estimators=300 ................
# [CV] . criterion=entropy, max_depth=1, n_estimators=300, total=   1.7s
# [CV] criterion=entropy, max_depth=1, n_estimators=300 ................
# [CV] . criterion=entropy, max_depth=1, n_estimators=300, total=   1.4s
# [CV] criterion=entropy, max_depth=1, n_estimators=300 ................
# [CV] . criterion=entropy, max_depth=1, n_estimators=300, total=   1.0s
# [CV] criterion=entropy, max_depth=1, n_estimators=300 ................
# [CV] . criterion=entropy, max_depth=1, n_estimators=300, total=   0.9s
# [CV] criterion=entropy, max_depth=1, n_estimators=400 ................
# [CV] . criterion=entropy, max_depth=1, n_estimators=400, total=   1.3s
# [CV] criterion=entropy, max_depth=1, n_estimators=400 ................
# [CV] . criterion=entropy, max_depth=1, n_estimators=400, total=   1.2s
# [CV] criterion=entropy, max_depth=1, n_estimators=400 ................
# [CV] . criterion=entropy, max_depth=1, n_estimators=400, total=   1.1s
# [CV] criterion=entropy, max_depth=1, n_estimators=400 ................
# [CV] . criterion=entropy, max_depth=1, n_estimators=400, total=   1.1s
# [CV] criterion=entropy, max_depth=1, n_estimators=400 ................
# [CV] . criterion=entropy, max_depth=1, n_estimators=400, total=   1.1s
# [CV] criterion=entropy, max_depth=3, n_estimators=100 ................
# [CV] . criterion=entropy, max_depth=3, n_estimators=100, total=   0.4s
# [CV] criterion=entropy, max_depth=3, n_estimators=100 ................
# [CV] . criterion=entropy, max_depth=3, n_estimators=100, total=   0.4s
# [CV] criterion=entropy, max_depth=3, n_estimators=100 ................
# [CV] . criterion=entropy, max_depth=3, n_estimators=100, total=   0.4s
# [CV] criterion=entropy, max_depth=3, n_estimators=100 ................
# [CV] . criterion=entropy, max_depth=3, n_estimators=100, total=   0.4s
# [CV] criterion=entropy, max_depth=3, n_estimators=100 ................
# [CV] . criterion=entropy, max_depth=3, n_estimators=100, total=   0.4s
# [CV] criterion=entropy, max_depth=3, n_estimators=200 ................
# [CV] . criterion=entropy, max_depth=3, n_estimators=200, total=   0.6s
# [CV] criterion=entropy, max_depth=3, n_estimators=200 ................
# [CV] . criterion=entropy, max_depth=3, n_estimators=200, total=   0.7s
# [CV] criterion=entropy, max_depth=3, n_estimators=200 ................
# [CV] . criterion=entropy, max_depth=3, n_estimators=200, total=   0.6s
# [CV] criterion=entropy, max_depth=3, n_estimators=200 ................
# [CV] . criterion=entropy, max_depth=3, n_estimators=200, total=   0.6s
# [CV] criterion=entropy, max_depth=3, n_estimators=200 ................
# [CV] . criterion=entropy, max_depth=3, n_estimators=200, total=   0.6s
# [CV] criterion=entropy, max_depth=3, n_estimators=300 ................
# [CV] . criterion=entropy, max_depth=3, n_estimators=300, total=   1.0s
# [CV] criterion=entropy, max_depth=3, n_estimators=300 ................
# [CV] . criterion=entropy, max_depth=3, n_estimators=300, total=   1.0s
# [CV] criterion=entropy, max_depth=3, n_estimators=300 ................
# [CV] . criterion=entropy, max_depth=3, n_estimators=300, total=   1.0s
# [CV] criterion=entropy, max_depth=3, n_estimators=300 ................
# [CV] . criterion=entropy, max_depth=3, n_estimators=300, total=   0.9s
# [CV] criterion=entropy, max_depth=3, n_estimators=300 ................
# [CV] . criterion=entropy, max_depth=3, n_estimators=300, total=   1.0s
# [CV] criterion=entropy, max_depth=3, n_estimators=400 ................
# [CV] . criterion=entropy, max_depth=3, n_estimators=400, total=   1.3s
# [CV] criterion=entropy, max_depth=3, n_estimators=400 ................
# [CV] . criterion=entropy, max_depth=3, n_estimators=400, total=   1.2s
# [CV] criterion=entropy, max_depth=3, n_estimators=400 ................
# [CV] . criterion=entropy, max_depth=3, n_estimators=400, total=   1.2s
# [CV] criterion=entropy, max_depth=3, n_estimators=400 ................
# [CV] . criterion=entropy, max_depth=3, n_estimators=400, total=   1.2s
# [CV] criterion=entropy, max_depth=3, n_estimators=400 ................
# [CV] . criterion=entropy, max_depth=3, n_estimators=400, total=   1.2s
# [CV] criterion=entropy, max_depth=5, n_estimators=100 ................
# [CV] . criterion=entropy, max_depth=5, n_estimators=100, total=   0.4s
# [CV] criterion=entropy, max_depth=5, n_estimators=100 ................
# [CV] . criterion=entropy, max_depth=5, n_estimators=100, total=   0.5s
# [CV] criterion=entropy, max_depth=5, n_estimators=100 ................
# [CV] . criterion=entropy, max_depth=5, n_estimators=100, total=   0.4s
# [CV] criterion=entropy, max_depth=5, n_estimators=100 ................
# [CV] . criterion=entropy, max_depth=5, n_estimators=100, total=   0.5s
# [CV] criterion=entropy, max_depth=5, n_estimators=100 ................
# [CV] . criterion=entropy, max_depth=5, n_estimators=100, total=   0.6s
# [CV] criterion=entropy, max_depth=5, n_estimators=200 ................
# [CV] . criterion=entropy, max_depth=5, n_estimators=200, total=   1.0s
# [CV] criterion=entropy, max_depth=5, n_estimators=200 ................
# [CV] . criterion=entropy, max_depth=5, n_estimators=200, total=   0.9s
# [CV] criterion=entropy, max_depth=5, n_estimators=200 ................
# [CV] . criterion=entropy, max_depth=5, n_estimators=200, total=   0.7s
# [CV] criterion=entropy, max_depth=5, n_estimators=200 ................
# [CV] . criterion=entropy, max_depth=5, n_estimators=200, total=   0.7s
# [CV] criterion=entropy, max_depth=5, n_estimators=200 ................
# [CV] . criterion=entropy, max_depth=5, n_estimators=200, total=   0.9s
# [CV] criterion=entropy, max_depth=5, n_estimators=300 ................
# [CV] . criterion=entropy, max_depth=5, n_estimators=300, total=   1.0s
# [CV] criterion=entropy, max_depth=5, n_estimators=300 ................
# [CV] . criterion=entropy, max_depth=5, n_estimators=300, total=   1.3s
# [CV] criterion=entropy, max_depth=5, n_estimators=300 ................
# [CV] . criterion=entropy, max_depth=5, n_estimators=300, total=   1.1s
# [CV] criterion=entropy, max_depth=5, n_estimators=300 ................
# [CV] . criterion=entropy, max_depth=5, n_estimators=300, total=   1.1s
# [CV] criterion=entropy, max_depth=5, n_estimators=300 ................
# [CV] . criterion=entropy, max_depth=5, n_estimators=300, total=   1.1s
# [CV] criterion=entropy, max_depth=5, n_estimators=400 ................
# [CV] . criterion=entropy, max_depth=5, n_estimators=400, total=   1.3s
# [CV] criterion=entropy, max_depth=5, n_estimators=400 ................
# [CV] . criterion=entropy, max_depth=5, n_estimators=400, total=   1.3s
# [CV] criterion=entropy, max_depth=5, n_estimators=400 ................
# [CV] . criterion=entropy, max_depth=5, n_estimators=400, total=   1.3s
# [CV] criterion=entropy, max_depth=5, n_estimators=400 ................
# [CV] . criterion=entropy, max_depth=5, n_estimators=400, total=   1.3s
# [CV] criterion=entropy, max_depth=5, n_estimators=400 ................
# [CV] . criterion=entropy, max_depth=5, n_estimators=400, total=   1.3s
# [CV] criterion=entropy, max_depth=7, n_estimators=100 ................
# [CV] . criterion=entropy, max_depth=7, n_estimators=100, total=   0.5s
# [CV] criterion=entropy, max_depth=7, n_estimators=100 ................
# [CV] . criterion=entropy, max_depth=7, n_estimators=100, total=   0.5s
# [CV] criterion=entropy, max_depth=7, n_estimators=100 ................
# [CV] . criterion=entropy, max_depth=7, n_estimators=100, total=   0.5s
# [CV] criterion=entropy, max_depth=7, n_estimators=100 ................
# [CV] . criterion=entropy, max_depth=7, n_estimators=100, total=   0.5s
# [CV] criterion=entropy, max_depth=7, n_estimators=100 ................
# [CV] . criterion=entropy, max_depth=7, n_estimators=100, total=   0.5s
# [CV] criterion=entropy, max_depth=7, n_estimators=200 ................
# [CV] . criterion=entropy, max_depth=7, n_estimators=200, total=   0.8s
# [CV] criterion=entropy, max_depth=7, n_estimators=200 ................
# [CV] . criterion=entropy, max_depth=7, n_estimators=200, total=   0.8s
# [CV] criterion=entropy, max_depth=7, n_estimators=200 ................
# [CV] . criterion=entropy, max_depth=7, n_estimators=200, total=   1.0s
# [CV] criterion=entropy, max_depth=7, n_estimators=200 ................
# [CV] . criterion=entropy, max_depth=7, n_estimators=200, total=   0.8s
# [CV] criterion=entropy, max_depth=7, n_estimators=200 ................
# [CV] . criterion=entropy, max_depth=7, n_estimators=200, total=   0.8s
# [CV] criterion=entropy, max_depth=7, n_estimators=300 ................
# [CV] . criterion=entropy, max_depth=7, n_estimators=300, total=   1.3s
# [CV] criterion=entropy, max_depth=7, n_estimators=300 ................
# [CV] . criterion=entropy, max_depth=7, n_estimators=300, total=   1.1s
# [CV] criterion=entropy, max_depth=7, n_estimators=300 ................
# [CV] . criterion=entropy, max_depth=7, n_estimators=300, total=   1.2s
# [CV] criterion=entropy, max_depth=7, n_estimators=300 ................
# [CV] . criterion=entropy, max_depth=7, n_estimators=300, total=   1.2s
# [CV] criterion=entropy, max_depth=7, n_estimators=300 ................
# [CV] . criterion=entropy, max_depth=7, n_estimators=300, total=   1.4s
# [CV] criterion=entropy, max_depth=7, n_estimators=400 ................
# [CV] . criterion=entropy, max_depth=7, n_estimators=400, total=   2.0s
# [CV] criterion=entropy, max_depth=7, n_estimators=400 ................
# [CV] . criterion=entropy, max_depth=7, n_estimators=400, total=   1.5s
# [CV] criterion=entropy, max_depth=7, n_estimators=400 ................
# [CV] . criterion=entropy, max_depth=7, n_estimators=400, total=   1.5s
# [CV] criterion=entropy, max_depth=7, n_estimators=400 ................
# [CV] . criterion=entropy, max_depth=7, n_estimators=400, total=   1.5s
# [CV] criterion=entropy, max_depth=7, n_estimators=400 ................
# [CV] . criterion=entropy, max_depth=7, n_estimators=400, total=   1.7s
# [CV] criterion=entropy, max_depth=9, n_estimators=100 ................
# [CV] . criterion=entropy, max_depth=9, n_estimators=100, total=   0.9s
# [CV] criterion=entropy, max_depth=9, n_estimators=100 ................
# [CV] . criterion=entropy, max_depth=9, n_estimators=100, total=   0.5s
# [CV] criterion=entropy, max_depth=9, n_estimators=100 ................
# [CV] . criterion=entropy, max_depth=9, n_estimators=100, total=   0.6s
# [CV] criterion=entropy, max_depth=9, n_estimators=100 ................
# [CV] . criterion=entropy, max_depth=9, n_estimators=100, total=   1.0s
# [CV] criterion=entropy, max_depth=9, n_estimators=100 ................
# [CV] . criterion=entropy, max_depth=9, n_estimators=100, total=   0.5s
# [CV] criterion=entropy, max_depth=9, n_estimators=200 ................
# [CV] . criterion=entropy, max_depth=9, n_estimators=200, total=   1.5s
# [CV] criterion=entropy, max_depth=9, n_estimators=200 ................
# [CV] . criterion=entropy, max_depth=9, n_estimators=200, total=   1.0s
# [CV] criterion=entropy, max_depth=9, n_estimators=200 ................
# [CV] . criterion=entropy, max_depth=9, n_estimators=200, total=   1.4s
# [CV] criterion=entropy, max_depth=9, n_estimators=200 ................
# [CV] . criterion=entropy, max_depth=9, n_estimators=200, total=   1.0s
# [CV] criterion=entropy, max_depth=9, n_estimators=200 ................
# [CV] . criterion=entropy, max_depth=9, n_estimators=200, total=   1.3s
# [CV] criterion=entropy, max_depth=9, n_estimators=300 ................
# [CV] . criterion=entropy, max_depth=9, n_estimators=300, total=   1.3s
# [CV] criterion=entropy, max_depth=9, n_estimators=300 ................
# [CV] . criterion=entropy, max_depth=9, n_estimators=300, total=   1.4s
# [CV] criterion=entropy, max_depth=9, n_estimators=300 ................
# [CV] . criterion=entropy, max_depth=9, n_estimators=300, total=   1.4s
# [CV] criterion=entropy, max_depth=9, n_estimators=300 ................
# [CV] . criterion=entropy, max_depth=9, n_estimators=300, total=   1.4s
# [CV] criterion=entropy, max_depth=9, n_estimators=300 ................
# [CV] . criterion=entropy, max_depth=9, n_estimators=300, total=   1.3s
# [CV] criterion=entropy, max_depth=9, n_estimators=400 ................
# [CV] . criterion=entropy, max_depth=9, n_estimators=400, total=   1.9s
# [CV] criterion=entropy, max_depth=9, n_estimators=400 ................
# [CV] . criterion=entropy, max_depth=9, n_estimators=400, total=   2.1s
# [CV] criterion=entropy, max_depth=9, n_estimators=400 ................
# [CV] . criterion=entropy, max_depth=9, n_estimators=400, total=   2.3s
# [CV] criterion=entropy, max_depth=9, n_estimators=400 ................
# [CV] . criterion=entropy, max_depth=9, n_estimators=400, total=   2.2s
# [CV] criterion=entropy, max_depth=9, n_estimators=400 ................
# [CV] . criterion=entropy, max_depth=9, n_estimators=400, total=   2.0s
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:  3.2min finished
# GridSearchCV(cv=5, estimator=RandomForestClassifier(n_jobs=-1), n_jobs=1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [1, 3, 5, 7, 9],
#                          'n_estimators': [100, 200, 300, 400]},
#              verbose=2)

# %%
# print the best score and estimator 
print(model.best_score_)
print(model.best_estimator_.get_params())
# Out:
# 0.882
# {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'entropy', 'max_depth': 9, 'max_features': 'auto', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 300, 'n_jobs': -1, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}
