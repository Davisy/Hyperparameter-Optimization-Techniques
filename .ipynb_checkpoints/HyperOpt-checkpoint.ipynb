# %% [markdown]
# ### HYPERPARAMETER OPTIMIZATION WITH HYPEROPT

# %%
# import packages 
import numpy as np 
import pandas as pd 
from sklearn.ensemble import RandomForestClassifier 
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler 
from hyperopt import tpe, hp, fmin, STATUS_OK,Trials
from hyperopt.pyll.base import scope

import warnings
warnings.filterwarnings("ignore")

# %%
# load data 
data = pd.read_csv("data/mobile_price_data.csv")

# %%
#read data 
data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
#
# [5 rows x 21 columns]

# %%
#show shape
data.shape
# Out:
# (2000, 21)

# %%
#show list of columns 
list(data.columns)
# Out:
# ['battery_power',
#  'blue',
#  'clock_speed',
#  'dual_sim',
#  'fc',
#  'four_g',
#  'int_memory',
#  'm_dep',
#  'mobile_wt',
#  'n_cores',
#  'pc',
#  'px_height',
#  'px_width',
#  'ram',
#  'sc_h',
#  'sc_w',
#  'talk_time',
#  'three_g',
#  'touch_screen',
#  'wifi',
#  'price_range']

# %%
# show data properties
data.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# min       0.000000     2.000000     0.100000    80.000000     1.000000  ...
# 25%       0.000000    16.000000     0.200000   109.000000     3.000000  ...
# 50%       1.000000    32.000000     0.500000   141.000000     4.000000  ...
# 75%       1.000000    48.000000     0.800000   170.000000     7.000000  ...
# max       1.000000    64.000000     1.000000   200.000000     8.000000  ...
#
#          px_height     px_width          ram         sc_h         sc_w  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean    645.108000  1251.515500  2124.213000    12.306500     5.767000
# std     443.780811   432.199447  1084.732044     4.213245     4.356398
# min       0.000000   500.000000   256.000000     5.000000     0.000000
# 25%     282.750000   874.750000  1207.500000     9.000000     2.000000
# 50%     564.000000  1247.000000  2146.500000    12.000000     5.000000
# 75%     947.250000  1633.000000  3064.500000    16.000000     9.000000
# max    1960.000000  1998.000000  3998.000000    19.000000    18.000000
#
#          talk_time      three_g  touch_screen         wifi  price_range
# count  2000.000000  2000.000000   2000.000000  2000.000000  2000.000000
# mean     11.011000     0.761500      0.503000     0.507000     1.500000
# std       5.463955     0.426273      0.500116     0.500076     1.118314
# min       2.000000     0.000000      0.000000     0.000000     0.000000
# 25%       6.000000     1.000000      0.000000     0.000000     0.750000
# 50%      11.000000     1.000000      1.000000     1.000000     1.500000
# 75%      16.000000     1.000000      1.000000     1.000000     2.250000
# max      20.000000     1.000000      1.000000     1.000000     3.000000
#
# [8 rows x 21 columns]

# %%
# show data information 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
#  18  touch_screen   2000 non-null   int64
#  19  wifi           2000 non-null   int64
#  20  price_range    2000 non-null   int64
# dtypes: float64(2), int64(19)
# memory usage: 328.2 KB

# %%
# check if it has missing values 
data.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
# split data into features and target 
X = data.drop("price_range", axis=1).values 
y = data.price_range.values

# %%
# standardize the feature variables 
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# define parameter space

space = {
    "n_estimators": hp.choice("n_estimators", [100, 200, 300, 400,500,600]),
    "max_depth": hp.quniform("max_depth", 1, 15,1),
    "criterion": hp.choice("criterion", ["gini", "entropy"]),
}

# %%
# define objective function

def hyperparameter_tuning(params):
    clf = RandomForestClassifier(**params,n_jobs=-1)
    acc = cross_val_score(clf, X_scaled, y,scoring="accuracy").mean()
    return {"loss": -acc, "status": STATUS_OK}

# %%
# Fine tune the model
trials = Trials()

best = fmin(
    fn=hyperparameter_tuning,
    space = space, 
    algo=tpe.suggest, 
    max_evals=100, 
    trials=trials
)

print("Best: {}".format(best))
# Out:
# 100%|█████████████████████████████████████████████████████████| 100/100 [10:30<00:00,  6.30s/trial, best loss: -0.8915]
# Best: {'criterion': 1, 'max_depth': 11.0, 'n_estimators': 2}

# %%
# A list of dictionaries representing everything about the search

trials.trials
# Out:
# [{'state': 2,
#   'tid': 0,
#   'spec': None,
#   'result': {'loss': -0.8790000000000001, 'status': 'ok'},
#   'misc': {'tid': 0,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [0], 'max_depth': [0], 'n_estimators': [0]},
#    'vals': {'criterion': [1], 'max_depth': [10.0], 'n_estimators': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 19, 31, 375000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 19, 39, 277000)},
#  {'state': 2,
#   'tid': 1,
#   'spec': None,
#   'result': {'loss': -0.877, 'status': 'ok'},
#   'misc': {'tid': 1,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [1], 'max_depth': [1], 'n_estimators': [1]},
#    'vals': {'criterion': [0], 'max_depth': [13.0], 'n_estimators': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 19, 39, 285000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 19, 41, 394000)},
#  {'state': 2,
#   'tid': 2,
#   'spec': None,
#   'result': {'loss': -0.768, 'status': 'ok'},
#   'misc': {'tid': 2,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [2], 'max_depth': [2], 'n_estimators': [2]},
#    'vals': {'criterion': [1], 'max_depth': [3.0], 'n_estimators': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 19, 41, 405000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 19, 46, 422000)},
#  {'state': 2,
#   'tid': 3,
#   'spec': None,
#   'result': {'loss': -0.8205, 'status': 'ok'},
#   'misc': {'tid': 3,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [3], 'max_depth': [3], 'n_estimators': [3]},
#    'vals': {'criterion': [0], 'max_depth': [4.0], 'n_estimators': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 19, 46, 427000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 19, 49, 204000)},
#  {'state': 2,
#   'tid': 4,
#   'spec': None,
#   'result': {'loss': -0.8720000000000001, 'status': 'ok'},
#   'misc': {'tid': 4,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [4], 'max_depth': [4], 'n_estimators': [4]},
#    'vals': {'criterion': [0], 'max_depth': [8.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 19, 49, 215000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 19, 53, 750000)},
#  {'state': 2,
#   'tid': 5,
#   'spec': None,
#   'result': {'loss': -0.883, 'status': 'ok'},
#   'misc': {'tid': 5,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [5], 'max_depth': [5], 'n_estimators': [5]},
#    'vals': {'criterion': [1], 'max_depth': [9.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 19, 53, 773000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 19, 59, 427000)},
#  {'state': 2,
#   'tid': 6,
#   'spec': None,
#   'result': {'loss': -0.8554999999999999, 'status': 'ok'},
#   'misc': {'tid': 6,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [6], 'max_depth': [6], 'n_estimators': [6]},
#    'vals': {'criterion': [0], 'max_depth': [6.0], 'n_estimators': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 19, 59, 434000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 20, 7, 111000)},
#  {'state': 2,
#   'tid': 7,
#   'spec': None,
#   'result': {'loss': -0.8789999999999999, 'status': 'ok'},
#   'misc': {'tid': 7,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [7], 'max_depth': [7], 'n_estimators': [7]},
#    'vals': {'criterion': [0], 'max_depth': [9.0], 'n_estimators': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 20, 7, 117000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 20, 13, 447000)},
#  {'state': 2,
#   'tid': 8,
#   'spec': None,
#   'result': {'loss': -0.595, 'status': 'ok'},
#   'misc': {'tid': 8,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [8], 'max_depth': [8], 'n_estimators': [8]},
#    'vals': {'criterion': [0], 'max_depth': [1.0], 'n_estimators': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 20, 13, 453000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 20, 18, 499000)},
#  {'state': 2,
#   'tid': 9,
#   'spec': None,
#   'result': {'loss': -0.8765000000000001, 'status': 'ok'},
#   'misc': {'tid': 9,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [9], 'max_depth': [9], 'n_estimators': [9]},
#    'vals': {'criterion': [0], 'max_depth': [12.0], 'n_estimators': [5]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 20, 18, 507000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 20, 27, 931000)},
#  {'state': 2,
#   'tid': 10,
#   'spec': None,
#   'result': {'loss': -0.877, 'status': 'ok'},
#   'misc': {'tid': 10,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [10], 'max_depth': [10], 'n_estimators': [10]},
#    'vals': {'criterion': [0], 'max_depth': [11.0], 'n_estimators': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 20, 27, 939000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 20, 31, 626000)},
#  {'state': 2,
#   'tid': 11,
#   'spec': None,
#   'result': {'loss': -0.8775000000000001, 'status': 'ok'},
#   'misc': {'tid': 11,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [11], 'max_depth': [11], 'n_estimators': [11]},
#    'vals': {'criterion': [0], 'max_depth': [11.0], 'n_estimators': [5]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 20, 31, 634000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 20, 40, 672000)},
#  {'state': 2,
#   'tid': 12,
#   'spec': None,
#   'result': {'loss': -0.776, 'status': 'ok'},
#   'misc': {'tid': 12,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [12], 'max_depth': [12], 'n_estimators': [12]},
#    'vals': {'criterion': [1], 'max_depth': [3.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 20, 40, 701000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 20, 44, 977000)},
#  {'state': 2,
#   'tid': 13,
#   'spec': None,
#   'result': {'loss': -0.882, 'status': 'ok'},
#   'misc': {'tid': 13,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [13], 'max_depth': [13], 'n_estimators': [13]},
#    'vals': {'criterion': [1], 'max_depth': [9.0], 'n_estimators': [5]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 20, 44, 983000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 20, 55, 312000)},
#  {'state': 2,
#   'tid': 14,
#   'spec': None,
#   'result': {'loss': -0.8744999999999999, 'status': 'ok'},
#   'misc': {'tid': 14,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [14], 'max_depth': [14], 'n_estimators': [14]},
#    'vals': {'criterion': [1], 'max_depth': [9.0], 'n_estimators': [5]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 20, 55, 323000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 21, 6, 59000)},
#  {'state': 2,
#   'tid': 15,
#   'spec': None,
#   'result': {'loss': -0.825, 'status': 'ok'},
#   'misc': {'tid': 15,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [15], 'max_depth': [15], 'n_estimators': [15]},
#    'vals': {'criterion': [1], 'max_depth': [4.0], 'n_estimators': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 21, 6, 71000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 21, 12, 948000)},
#  {'state': 2,
#   'tid': 16,
#   'spec': None,
#   'result': {'loss': -0.757, 'status': 'ok'},
#   'misc': {'tid': 16,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [16], 'max_depth': [16], 'n_estimators': [16]},
#    'vals': {'criterion': [0], 'max_depth': [2.0], 'n_estimators': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 21, 12, 963000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 21, 17, 423000)},
#  {'state': 2,
#   'tid': 17,
#   'spec': None,
#   'result': {'loss': -0.8765000000000001, 'status': 'ok'},
#   'misc': {'tid': 17,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [17], 'max_depth': [17], 'n_estimators': [17]},
#    'vals': {'criterion': [1], 'max_depth': [8.0], 'n_estimators': [5]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 21, 17, 429000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 21, 27, 190000)},
#  {'state': 2,
#   'tid': 18,
#   'spec': None,
#   'result': {'loss': -0.674, 'status': 'ok'},
#   'misc': {'tid': 18,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [18], 'max_depth': [18], 'n_estimators': [18]},
#    'vals': {'criterion': [1], 'max_depth': [2.0], 'n_estimators': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 21, 27, 201000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 21, 32, 219000)},
#  {'state': 2,
#   'tid': 19,
#   'spec': None,
#   'result': {'loss': -0.843, 'status': 'ok'},
#   'misc': {'tid': 19,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [19], 'max_depth': [19], 'n_estimators': [19]},
#    'vals': {'criterion': [1], 'max_depth': [5.0], 'n_estimators': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 21, 32, 231000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 21, 37, 668000)},
#  {'state': 2,
#   'tid': 20,
#   'spec': None,
#   'result': {'loss': -0.8579999999999999, 'status': 'ok'},
#   'misc': {'tid': 20,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [20], 'max_depth': [20], 'n_estimators': [20]},
#    'vals': {'criterion': [1], 'max_depth': [6.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 21, 37, 677000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 21, 42, 497000)},
#  {'state': 2,
#   'tid': 21,
#   'spec': None,
#   'result': {'loss': -0.876, 'status': 'ok'},
#   'misc': {'tid': 21,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [21], 'max_depth': [21], 'n_estimators': [21]},
#    'vals': {'criterion': [1], 'max_depth': [14.0], 'n_estimators': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 21, 42, 523000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 21, 44, 993000)},
#  {'state': 2,
#   'tid': 22,
#   'spec': None,
#   'result': {'loss': -0.866, 'status': 'ok'},
#   'misc': {'tid': 22,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [22], 'max_depth': [22], 'n_estimators': [22]},
#    'vals': {'criterion': [1], 'max_depth': [7.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 21, 45, 26000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 21, 50, 63000)},
#  {'state': 2,
#   'tid': 23,
#   'spec': None,
#   'result': {'loss': -0.881, 'status': 'ok'},
#   'misc': {'tid': 23,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [23], 'max_depth': [23], 'n_estimators': [23]},
#    'vals': {'criterion': [1], 'max_depth': [10.0], 'n_estimators': [5]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 21, 50, 91000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 22, 0, 196000)},
#  {'state': 2,
#   'tid': 24,
#   'spec': None,
#   'result': {'loss': -0.8825, 'status': 'ok'},
#   'misc': {'tid': 24,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [24], 'max_depth': [24], 'n_estimators': [24]},
#    'vals': {'criterion': [1], 'max_depth': [14.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 22, 0, 222000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 22, 6, 480000)},
#  {'state': 2,
#   'tid': 25,
#   'spec': None,
#   'result': {'loss': -0.8879999999999999, 'status': 'ok'},
#   'misc': {'tid': 25,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [25], 'max_depth': [25], 'n_estimators': [25]},
#    'vals': {'criterion': [1], 'max_depth': [14.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 22, 6, 514000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 22, 12, 445000)},
#  {'state': 2,
#   'tid': 26,
#   'spec': None,
#   'result': {'loss': -0.8895, 'status': 'ok'},
#   'misc': {'tid': 26,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [26], 'max_depth': [26], 'n_estimators': [26]},
#    'vals': {'criterion': [1], 'max_depth': [15.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 22, 12, 482000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 22, 18, 465000)},
#  {'state': 2,
#   'tid': 27,
#   'spec': None,
#   'result': {'loss': -0.8875, 'status': 'ok'},
#   'misc': {'tid': 27,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [27], 'max_depth': [27], 'n_estimators': [27]},
#    'vals': {'criterion': [1], 'max_depth': [15.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 22, 18, 478000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 22, 24, 386000)},
#  {'state': 2,
#   'tid': 28,
#   'spec': None,
#   'result': {'loss': -0.8805, 'status': 'ok'},
#   'misc': {'tid': 28,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [28], 'max_depth': [28], 'n_estimators': [28]},
#    'vals': {'criterion': [1], 'max_depth': [15.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 22, 24, 414000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 22, 30, 480000)},
#  {'state': 2,
#   'tid': 29,
#   'spec': None,
#   'result': {'loss': -0.8855000000000001, 'status': 'ok'},
#   'misc': {'tid': 29,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [29], 'max_depth': [29], 'n_estimators': [29]},
#    'vals': {'criterion': [1], 'max_depth': [13.0], 'n_estimators': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 22, 30, 514000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 22, 35, 598000)},
#  {'state': 2,
#   'tid': 30,
#   'spec': None,
#   'result': {'loss': -0.873, 'status': 'ok'},
#   'misc': {'tid': 30,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [30], 'max_depth': [30], 'n_estimators': [30]},
#    'vals': {'criterion': [1], 'max_depth': [14.0], 'n_estimators': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 22, 35, 616000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 22, 38, 258000)},
#  {'state': 2,
#   'tid': 31,
#   'spec': None,
#   'result': {'loss': -0.8880000000000001, 'status': 'ok'},
#   'misc': {'tid': 31,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [31], 'max_depth': [31], 'n_estimators': [31]},
#    'vals': {'criterion': [1], 'max_depth': [12.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 22, 38, 280000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 22, 44, 783000)},
#  {'state': 2,
#   'tid': 32,
#   'spec': None,
#   'result': {'loss': -0.8865000000000001, 'status': 'ok'},
#   'misc': {'tid': 32,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [32], 'max_depth': [32], 'n_estimators': [32]},
#    'vals': {'criterion': [1], 'max_depth': [12.0], 'n_estimators': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 22, 44, 800000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 22, 54, 894000)},
#  {'state': 2,
#   'tid': 33,
#   'spec': None,
#   'result': {'loss': -0.8875, 'status': 'ok'},
#   'misc': {'tid': 33,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [33], 'max_depth': [33], 'n_estimators': [33]},
#    'vals': {'criterion': [1], 'max_depth': [13.0], 'n_estimators': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 22, 54, 908000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 22, 57, 386000)},
#  {'state': 2,
#   'tid': 34,
#   'spec': None,
#   'result': {'loss': -0.8869999999999999, 'status': 'ok'},
#   'misc': {'tid': 34,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [34], 'max_depth': [34], 'n_estimators': [34]},
#    'vals': {'criterion': [1], 'max_depth': [12.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 22, 57, 418000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 23, 3, 987000)},
#  {'state': 2,
#   'tid': 35,
#   'spec': None,
#   'result': {'loss': -0.8915, 'status': 'ok'},
#   'misc': {'tid': 35,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [35], 'max_depth': [35], 'n_estimators': [35]},
#    'vals': {'criterion': [1], 'max_depth': [11.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 23, 4, 15000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 23, 9, 960000)},
#  {'state': 2,
#   'tid': 36,
#   'spec': None,
#   'result': {'loss': -0.8780000000000001, 'status': 'ok'},
#   'misc': {'tid': 36,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [36], 'max_depth': [36], 'n_estimators': [36]},
#    'vals': {'criterion': [1], 'max_depth': [10.0], 'n_estimators': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 23, 9, 999000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 23, 13, 973000)},
#  {'state': 2,
#   'tid': 37,
#   'spec': None,
#   'result': {'loss': -0.8885000000000002, 'status': 'ok'},
#   'misc': {'tid': 37,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [37], 'max_depth': [37], 'n_estimators': [37]},
#    'vals': {'criterion': [1], 'max_depth': [11.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 23, 14, 5000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 23, 19, 791000)},
#  {'state': 2,
#   'tid': 38,
#   'spec': None,
#   'result': {'loss': -0.8825, 'status': 'ok'},
#   'misc': {'tid': 38,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [38], 'max_depth': [38], 'n_estimators': [38]},
#    'vals': {'criterion': [0], 'max_depth': [15.0], 'n_estimators': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 23, 19, 805000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 23, 27, 727000)},
#  {'state': 2,
#   'tid': 39,
#   'spec': None,
#   'result': {'loss': -0.8785000000000001, 'status': 'ok'},
#   'misc': {'tid': 39,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [39], 'max_depth': [39], 'n_estimators': [39]},
#    'vals': {'criterion': [1], 'max_depth': [13.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 23, 27, 773000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 23, 33, 926000)},
#  {'state': 2,
#   'tid': 40,
#   'spec': None,
#   'result': {'loss': -0.8614999999999998, 'status': 'ok'},
#   'misc': {'tid': 40,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [40], 'max_depth': [40], 'n_estimators': [40]},
#    'vals': {'criterion': [0], 'max_depth': [7.0], 'n_estimators': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 23, 33, 958000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 23, 35, 951000)},
#  {'state': 2,
#   'tid': 41,
#   'spec': None,
#   'result': {'loss': -0.8795, 'status': 'ok'},
#   'misc': {'tid': 41,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [41], 'max_depth': [41], 'n_estimators': [41]},
#    'vals': {'criterion': [1], 'max_depth': [11.0], 'n_estimators': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 23, 35, 993000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 23, 39, 897000)},
#  {'state': 2,
#   'tid': 42,
#   'spec': None,
#   'result': {'loss': -0.8755, 'status': 'ok'},
#   'misc': {'tid': 42,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [42], 'max_depth': [42], 'n_estimators': [42]},
#    'vals': {'criterion': [0], 'max_depth': [8.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 23, 39, 931000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 23, 44, 616000)},
#  {'state': 2,
#   'tid': 43,
#   'spec': None,
#   'result': {'loss': -0.8835, 'status': 'ok'},
#   'misc': {'tid': 43,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [43], 'max_depth': [43], 'n_estimators': [43]},
#    'vals': {'criterion': [1], 'max_depth': [10.0], 'n_estimators': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 23, 44, 658000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 23, 53, 609000)},
#  {'state': 2,
#   'tid': 44,
#   'spec': None,
#   'result': {'loss': -0.867, 'status': 'ok'},
#   'misc': {'tid': 44,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [44], 'max_depth': [44], 'n_estimators': [44]},
#    'vals': {'criterion': [0], 'max_depth': [7.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 23, 53, 626000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 23, 58, 196000)},
#  {'state': 2,
#   'tid': 45,
#   'spec': None,
#   'result': {'loss': -0.8800000000000001, 'status': 'ok'},
#   'misc': {'tid': 45,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [45], 'max_depth': [45], 'n_estimators': [45]},
#    'vals': {'criterion': [1], 'max_depth': [10.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 23, 58, 213000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 24, 4, 700000)},
#  {'state': 2,
#   'tid': 46,
#   'spec': None,
#   'result': {'loss': -0.8819999999999999, 'status': 'ok'},
#   'misc': {'tid': 46,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [46], 'max_depth': [46], 'n_estimators': [46]},
#    'vals': {'criterion': [1], 'max_depth': [11.0], 'n_estimators': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 24, 4, 719000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 24, 8, 704000)},
#  {'state': 2,
#   'tid': 47,
#   'spec': None,
#   'result': {'loss': -0.8779999999999999, 'status': 'ok'},
#   'misc': {'tid': 47,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [47], 'max_depth': [47], 'n_estimators': [47]},
#    'vals': {'criterion': [0], 'max_depth': [9.0], 'n_estimators': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 24, 8, 732000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 24, 14, 575000)},
#  {'state': 2,
#   'tid': 48,
#   'spec': None,
#   'result': {'loss': -0.885, 'status': 'ok'},
#   'misc': {'tid': 48,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [48], 'max_depth': [48], 'n_estimators': [48]},
#    'vals': {'criterion': [1], 'max_depth': [13.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 24, 14, 593000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 24, 20, 668000)},
#  {'state': 2,
#   'tid': 49,
#   'spec': None,
#   'result': {'loss': -0.853, 'status': 'ok'},
#   'misc': {'tid': 49,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [49], 'max_depth': [49], 'n_estimators': [49]},
#    'vals': {'criterion': [1], 'max_depth': [6.0], 'n_estimators': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 24, 20, 744000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 24, 32, 165000)},
#  {'state': 2,
#   'tid': 50,
#   'spec': None,
#   'result': {'loss': -0.8799999999999999, 'status': 'ok'},
#   'misc': {'tid': 50,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [50], 'max_depth': [50], 'n_estimators': [50]},
#    'vals': {'criterion': [0], 'max_depth': [12.0], 'n_estimators': [5]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 24, 32, 208000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 24, 41, 989000)},
#  {'state': 2,
#   'tid': 51,
#   'spec': None,
#   'result': {'loss': -0.8100000000000002, 'status': 'ok'},
#   'misc': {'tid': 51,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [51], 'max_depth': [51], 'n_estimators': [51]},
#    'vals': {'criterion': [1], 'max_depth': [4.0], 'n_estimators': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 24, 42, 6000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 24, 44, 8000)},
#  {'state': 2,
#   'tid': 52,
#   'spec': None,
#   'result': {'loss': -0.8379999999999999, 'status': 'ok'},
#   'misc': {'tid': 52,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [52], 'max_depth': [52], 'n_estimators': [52]},
#    'vals': {'criterion': [1], 'max_depth': [5.0], 'n_estimators': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 24, 44, 55000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 24, 49, 445000)},
#  {'state': 2,
#   'tid': 53,
#   'spec': None,
#   'result': {'loss': -0.8879999999999999, 'status': 'ok'},
#   'misc': {'tid': 53,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [53], 'max_depth': [53], 'n_estimators': [53]},
#    'vals': {'criterion': [1], 'max_depth': [15.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 24, 49, 460000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 24, 55, 263000)},
#  {'state': 2,
#   'tid': 54,
#   'spec': None,
#   'result': {'loss': -0.8695, 'status': 'ok'},
#   'misc': {'tid': 54,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [54], 'max_depth': [54], 'n_estimators': [54]},
#    'vals': {'criterion': [0], 'max_depth': [8.0], 'n_estimators': [5]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 24, 55, 300000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 25, 4, 99000)},
#  {'state': 2,
#   'tid': 55,
#   'spec': None,
#   'result': {'loss': -0.8870000000000001, 'status': 'ok'},
#   'misc': {'tid': 55,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [55], 'max_depth': [55], 'n_estimators': [55]},
#    'vals': {'criterion': [1], 'max_depth': [14.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 25, 4, 126000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 25, 10, 67000)},
#  {'state': 2,
#   'tid': 56,
#   'spec': None,
#   'result': {'loss': -0.8815, 'status': 'ok'},
#   'misc': {'tid': 56,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [56], 'max_depth': [56], 'n_estimators': [56]},
#    'vals': {'criterion': [1], 'max_depth': [9.0], 'n_estimators': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 25, 10, 83000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 25, 14, 842000)},
#  {'state': 2,
#   'tid': 57,
#   'spec': None,
#   'result': {'loss': -0.8855000000000001, 'status': 'ok'},
#   'misc': {'tid': 57,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [57], 'max_depth': [57], 'n_estimators': [57]},
#    'vals': {'criterion': [1], 'max_depth': [13.0], 'n_estimators': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 25, 14, 858000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 25, 23, 278000)},
#  {'state': 2,
#   'tid': 58,
#   'spec': None,
#   'result': {'loss': -0.8795, 'status': 'ok'},
#   'misc': {'tid': 58,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [58], 'max_depth': [58], 'n_estimators': [58]},
#    'vals': {'criterion': [0], 'max_depth': [11.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 25, 23, 295000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 25, 28, 739000)},
#  {'state': 2,
#   'tid': 59,
#   'spec': None,
#   'result': {'loss': -0.5504999999999999, 'status': 'ok'},
#   'misc': {'tid': 59,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [59], 'max_depth': [59], 'n_estimators': [59]},
#    'vals': {'criterion': [1], 'max_depth': [1.0], 'n_estimators': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 25, 28, 793000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 25, 30, 776000)},
#  {'state': 2,
#   'tid': 60,
#   'spec': None,
#   'result': {'loss': -0.8860000000000001, 'status': 'ok'},
#   'misc': {'tid': 60,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [60], 'max_depth': [60], 'n_estimators': [60]},
#    'vals': {'criterion': [1], 'max_depth': [14.0], 'n_estimators': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 25, 30, 800000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 25, 41, 128000)},
#  {'state': 2,
#   'tid': 61,
#   'spec': None,
#   'result': {'loss': -0.7849999999999999, 'status': 'ok'},
#   'misc': {'tid': 61,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [61], 'max_depth': [61], 'n_estimators': [61]},
#    'vals': {'criterion': [1], 'max_depth': [3.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 25, 41, 161000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 25, 46, 621000)},
#  {'state': 2,
#   'tid': 62,
#   'spec': None,
#   'result': {'loss': -0.8844999999999998, 'status': 'ok'},
#   'misc': {'tid': 62,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [62], 'max_depth': [62], 'n_estimators': [62]},
#    'vals': {'criterion': [1], 'max_depth': [12.0], 'n_estimators': [5]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 25, 46, 662000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 25, 57, 687000)},
#  {'state': 2,
#   'tid': 63,
#   'spec': None,
#   'result': {'loss': -0.8610000000000001, 'status': 'ok'},
#   'misc': {'tid': 63,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [63], 'max_depth': [63], 'n_estimators': [63]},
#    'vals': {'criterion': [0], 'max_depth': [7.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 25, 57, 726000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 26, 2, 793000)},
#  {'state': 2,
#   'tid': 64,
#   'spec': None,
#   'result': {'loss': -0.8865000000000001, 'status': 'ok'},
#   'misc': {'tid': 64,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [64], 'max_depth': [64], 'n_estimators': [64]},
#    'vals': {'criterion': [1], 'max_depth': [15.0], 'n_estimators': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 26, 2, 807000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 26, 9, 994000)},
#  {'state': 2,
#   'tid': 65,
#   'spec': None,
#   'result': {'loss': -0.8880000000000001, 'status': 'ok'},
#   'misc': {'tid': 65,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [65], 'max_depth': [65], 'n_estimators': [65]},
#    'vals': {'criterion': [1], 'max_depth': [11.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 26, 10, 9000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 26, 15, 755000)},
#  {'state': 2,
#   'tid': 66,
#   'spec': None,
#   'result': {'loss': -0.883, 'status': 'ok'},
#   'misc': {'tid': 66,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [66], 'max_depth': [66], 'n_estimators': [66]},
#    'vals': {'criterion': [1], 'max_depth': [10.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 26, 15, 785000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 26, 21, 755000)},
#  {'state': 2,
#   'tid': 67,
#   'spec': None,
#   'result': {'loss': -0.8780000000000001, 'status': 'ok'},
#   'misc': {'tid': 67,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [67], 'max_depth': [67], 'n_estimators': [67]},
#    'vals': {'criterion': [1], 'max_depth': [9.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 26, 21, 778000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 26, 28, 112000)},
#  {'state': 2,
#   'tid': 68,
#   'spec': None,
#   'result': {'loss': -0.8815, 'status': 'ok'},
#   'misc': {'tid': 68,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [68], 'max_depth': [68], 'n_estimators': [68]},
#    'vals': {'criterion': [1], 'max_depth': [12.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 26, 28, 132000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 26, 37, 93000)},
#  {'state': 2,
#   'tid': 69,
#   'spec': None,
#   'result': {'loss': -0.8825, 'status': 'ok'},
#   'misc': {'tid': 69,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [69], 'max_depth': [69], 'n_estimators': [69]},
#    'vals': {'criterion': [1], 'max_depth': [10.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 26, 37, 123000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 26, 44, 915000)},
#  {'state': 2,
#   'tid': 70,
#   'spec': None,
#   'result': {'loss': -0.8854999999999998, 'status': 'ok'},
#   'misc': {'tid': 70,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [70], 'max_depth': [70], 'n_estimators': [70]},
#    'vals': {'criterion': [1], 'max_depth': [14.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 26, 44, 933000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 26, 51, 254000)},
#  {'state': 2,
#   'tid': 71,
#   'spec': None,
#   'result': {'loss': -0.8725000000000002, 'status': 'ok'},
#   'misc': {'tid': 71,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [71], 'max_depth': [71], 'n_estimators': [71]},
#    'vals': {'criterion': [1], 'max_depth': [8.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 26, 51, 270000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 26, 56, 747000)},
#  {'state': 2,
#   'tid': 72,
#   'spec': None,
#   'result': {'loss': -0.8485000000000001, 'status': 'ok'},
#   'misc': {'tid': 72,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [72], 'max_depth': [72], 'n_estimators': [72]},
#    'vals': {'criterion': [1], 'max_depth': [5.0], 'n_estimators': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 26, 56, 774000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 27, 0, 484000)},
#  {'state': 2,
#   'tid': 73,
#   'spec': None,
#   'result': {'loss': -0.882, 'status': 'ok'},
#   'misc': {'tid': 73,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [73], 'max_depth': [73], 'n_estimators': [73]},
#    'vals': {'criterion': [1], 'max_depth': [11.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 27, 0, 501000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 27, 7, 198000)},
#  {'state': 2,
#   'tid': 74,
#   'spec': None,
#   'result': {'loss': -0.882, 'status': 'ok'},
#   'misc': {'tid': 74,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [74], 'max_depth': [74], 'n_estimators': [74]},
#    'vals': {'criterion': [1], 'max_depth': [13.0], 'n_estimators': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 27, 7, 215000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 27, 9, 753000)},
#  {'state': 2,
#   'tid': 75,
#   'spec': None,
#   'result': {'loss': -0.8779999999999999, 'status': 'ok'},
#   'misc': {'tid': 75,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [75], 'max_depth': [75], 'n_estimators': [75]},
#    'vals': {'criterion': [1], 'max_depth': [9.0], 'n_estimators': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 27, 9, 792000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 27, 19, 542000)},
#  {'state': 2,
#   'tid': 76,
#   'spec': None,
#   'result': {'loss': -0.885, 'status': 'ok'},
#   'misc': {'tid': 76,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [76], 'max_depth': [76], 'n_estimators': [76]},
#    'vals': {'criterion': [1], 'max_depth': [12.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 27, 19, 586000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 27, 25, 702000)},
#  {'state': 2,
#   'tid': 77,
#   'spec': None,
#   'result': {'loss': -0.693, 'status': 'ok'},
#   'misc': {'tid': 77,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [77], 'max_depth': [77], 'n_estimators': [77]},
#    'vals': {'criterion': [1], 'max_depth': [2.0], 'n_estimators': [5]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 27, 25, 719000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 27, 34, 164000)},
#  {'state': 2,
#   'tid': 78,
#   'spec': None,
#   'result': {'loss': -0.8654999999999999, 'status': 'ok'},
#   'misc': {'tid': 78,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [78], 'max_depth': [78], 'n_estimators': [78]},
#    'vals': {'criterion': [1], 'max_depth': [6.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 27, 34, 198000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 27, 40, 390000)},
#  {'state': 2,
#   'tid': 79,
#   'spec': None,
#   'result': {'loss': -0.8785000000000001, 'status': 'ok'},
#   'misc': {'tid': 79,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [79], 'max_depth': [79], 'n_estimators': [79]},
#    'vals': {'criterion': [0], 'max_depth': [15.0], 'n_estimators': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 27, 40, 415000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 27, 44, 773000)},
#  {'state': 2,
#   'tid': 80,
#   'spec': None,
#   'result': {'loss': -0.8870000000000001, 'status': 'ok'},
#   'misc': {'tid': 80,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [80], 'max_depth': [80], 'n_estimators': [80]},
#    'vals': {'criterion': [1], 'max_depth': [13.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 27, 44, 793000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 27, 51, 398000)},
#  {'state': 2,
#   'tid': 81,
#   'spec': None,
#   'result': {'loss': -0.8865000000000001, 'status': 'ok'},
#   'misc': {'tid': 81,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [81], 'max_depth': [81], 'n_estimators': [81]},
#    'vals': {'criterion': [1], 'max_depth': [14.0], 'n_estimators': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 27, 51, 420000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 27, 59, 861000)},
#  {'state': 2,
#   'tid': 82,
#   'spec': None,
#   'result': {'loss': -0.8775000000000001, 'status': 'ok'},
#   'misc': {'tid': 82,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [82], 'max_depth': [82], 'n_estimators': [82]},
#    'vals': {'criterion': [1], 'max_depth': [11.0], 'n_estimators': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 27, 59, 891000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 28, 2, 814000)},
#  {'state': 2,
#   'tid': 83,
#   'spec': None,
#   'result': {'loss': -0.8744999999999999, 'status': 'ok'},
#   'misc': {'tid': 83,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [83], 'max_depth': [83], 'n_estimators': [83]},
#    'vals': {'criterion': [0], 'max_depth': [9.0], 'n_estimators': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 28, 2, 855000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 28, 10, 655000)},
#  {'state': 2,
#   'tid': 84,
#   'spec': None,
#   'result': {'loss': -0.8835, 'status': 'ok'},
#   'misc': {'tid': 84,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [84], 'max_depth': [84], 'n_estimators': [84]},
#    'vals': {'criterion': [1], 'max_depth': [10.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 28, 10, 675000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 28, 16, 605000)},
#  {'state': 2,
#   'tid': 85,
#   'spec': None,
#   'result': {'loss': -0.8665, 'status': 'ok'},
#   'misc': {'tid': 85,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [85], 'max_depth': [85], 'n_estimators': [85]},
#    'vals': {'criterion': [1], 'max_depth': [7.0], 'n_estimators': [5]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 28, 16, 626000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 28, 26, 701000)},
#  {'state': 2,
#   'tid': 86,
#   'spec': None,
#   'result': {'loss': -0.882, 'status': 'ok'},
#   'misc': {'tid': 86,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [86], 'max_depth': [86], 'n_estimators': [86]},
#    'vals': {'criterion': [1], 'max_depth': [12.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 28, 26, 720000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 28, 33, 361000)},
#  {'state': 2,
#   'tid': 87,
#   'spec': None,
#   'result': {'loss': -0.885, 'status': 'ok'},
#   'misc': {'tid': 87,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [87], 'max_depth': [87], 'n_estimators': [87]},
#    'vals': {'criterion': [1], 'max_depth': [10.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 28, 33, 394000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 28, 39, 481000)},
#  {'state': 2,
#   'tid': 88,
#   'spec': None,
#   'result': {'loss': -0.883, 'status': 'ok'},
#   'misc': {'tid': 88,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [88], 'max_depth': [88], 'n_estimators': [88]},
#    'vals': {'criterion': [0], 'max_depth': [13.0], 'n_estimators': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 28, 39, 505000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 28, 46, 145000)},
#  {'state': 2,
#   'tid': 89,
#   'spec': None,
#   'result': {'loss': -0.8800000000000001, 'status': 'ok'},
#   'misc': {'tid': 89,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [89], 'max_depth': [89], 'n_estimators': [89]},
#    'vals': {'criterion': [1], 'max_depth': [11.0], 'n_estimators': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 28, 46, 164000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 28, 50, 278000)},
#  {'state': 2,
#   'tid': 90,
#   'spec': None,
#   'result': {'loss': -0.8785000000000001, 'status': 'ok'},
#   'misc': {'tid': 90,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [90], 'max_depth': [90], 'n_estimators': [90]},
#    'vals': {'criterion': [1], 'max_depth': [8.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 28, 50, 325000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 28, 56, 874000)},
#  {'state': 2,
#   'tid': 91,
#   'spec': None,
#   'result': {'loss': -0.8789999999999999, 'status': 'ok'},
#   'misc': {'tid': 91,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [91], 'max_depth': [91], 'n_estimators': [91]},
#    'vals': {'criterion': [1], 'max_depth': [15.0], 'n_estimators': [0]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 28, 56, 898000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 28, 59, 450000)},
#  {'state': 2,
#   'tid': 92,
#   'spec': None,
#   'result': {'loss': -0.8845000000000001, 'status': 'ok'},
#   'misc': {'tid': 92,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [92], 'max_depth': [92], 'n_estimators': [92]},
#    'vals': {'criterion': [0], 'max_depth': [14.0], 'n_estimators': [4]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 28, 59, 477000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 29, 9, 343000)},
#  {'state': 2,
#   'tid': 93,
#   'spec': None,
#   'result': {'loss': -0.8225, 'status': 'ok'},
#   'misc': {'tid': 93,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [93], 'max_depth': [93], 'n_estimators': [93]},
#    'vals': {'criterion': [1], 'max_depth': [4.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 29, 9, 365000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 29, 15, 535000)},
#  {'state': 2,
#   'tid': 94,
#   'spec': None,
#   'result': {'loss': -0.8859999999999999, 'status': 'ok'},
#   'misc': {'tid': 94,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [94], 'max_depth': [94], 'n_estimators': [94]},
#    'vals': {'criterion': [1], 'max_depth': [13.0], 'n_estimators': [5]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 29, 15, 557000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 29, 29, 220000)},
#  {'state': 2,
#   'tid': 95,
#   'spec': None,
#   'result': {'loss': -0.8800000000000001, 'status': 'ok'},
#   'misc': {'tid': 95,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [95], 'max_depth': [95], 'n_estimators': [95]},
#    'vals': {'criterion': [1], 'max_depth': [12.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 29, 29, 247000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 29, 36, 318000)},
#  {'state': 2,
#   'tid': 96,
#   'spec': None,
#   'result': {'loss': -0.845, 'status': 'ok'},
#   'misc': {'tid': 96,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [96], 'max_depth': [96], 'n_estimators': [96]},
#    'vals': {'criterion': [1], 'max_depth': [5.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 29, 36, 340000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 29, 42, 214000)},
#  {'state': 2,
#   'tid': 97,
#   'spec': None,
#   'result': {'loss': -0.8045, 'status': 'ok'},
#   'misc': {'tid': 97,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [97], 'max_depth': [97], 'n_estimators': [97]},
#    'vals': {'criterion': [0], 'max_depth': [3.0], 'n_estimators': [1]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 29, 42, 251000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 29, 46, 3000)},
#  {'state': 2,
#   'tid': 98,
#   'spec': None,
#   'result': {'loss': -0.8549999999999999, 'status': 'ok'},
#   'misc': {'tid': 98,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [98], 'max_depth': [98], 'n_estimators': [98]},
#    'vals': {'criterion': [1], 'max_depth': [6.0], 'n_estimators': [3]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 29, 46, 31000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 29, 53, 217000)},
#  {'state': 2,
#   'tid': 99,
#   'spec': None,
#   'result': {'loss': -0.8800000000000001, 'status': 'ok'},
#   'misc': {'tid': 99,
#    'cmd': ('domain_attachment', 'FMinIter_Domain'),
#    'workdir': None,
#    'idxs': {'criterion': [99], 'max_depth': [99], 'n_estimators': [99]},
#    'vals': {'criterion': [1], 'max_depth': [8.0], 'n_estimators': [2]}},
#   'exp_key': None,
#   'owner': None,
#   'version': 0,
#   'book_time': datetime.datetime(2020, 9, 8, 14, 29, 53, 267000),
#   'refresh_time': datetime.datetime(2020, 9, 8, 14, 30, 1, 671000)}]

# %%
# A list of dictionaries returned by 'objective' during the search 
trials.results
# Out:
# [{'loss': -0.8790000000000001, 'status': 'ok'},
#  {'loss': -0.877, 'status': 'ok'},
#  {'loss': -0.768, 'status': 'ok'},
#  {'loss': -0.8205, 'status': 'ok'},
#  {'loss': -0.8720000000000001, 'status': 'ok'},
#  {'loss': -0.883, 'status': 'ok'},
#  {'loss': -0.8554999999999999, 'status': 'ok'},
#  {'loss': -0.8789999999999999, 'status': 'ok'},
#  {'loss': -0.595, 'status': 'ok'},
#  {'loss': -0.8765000000000001, 'status': 'ok'},
#  {'loss': -0.877, 'status': 'ok'},
#  {'loss': -0.8775000000000001, 'status': 'ok'},
#  {'loss': -0.776, 'status': 'ok'},
#  {'loss': -0.882, 'status': 'ok'},
#  {'loss': -0.8744999999999999, 'status': 'ok'},
#  {'loss': -0.825, 'status': 'ok'},
#  {'loss': -0.757, 'status': 'ok'},
#  {'loss': -0.8765000000000001, 'status': 'ok'},
#  {'loss': -0.674, 'status': 'ok'},
#  {'loss': -0.843, 'status': 'ok'},
#  {'loss': -0.8579999999999999, 'status': 'ok'},
#  {'loss': -0.876, 'status': 'ok'},
#  {'loss': -0.866, 'status': 'ok'},
#  {'loss': -0.881, 'status': 'ok'},
#  {'loss': -0.8825, 'status': 'ok'},
#  {'loss': -0.8879999999999999, 'status': 'ok'},
#  {'loss': -0.8895, 'status': 'ok'},
#  {'loss': -0.8875, 'status': 'ok'},
#  {'loss': -0.8805, 'status': 'ok'},
#  {'loss': -0.8855000000000001, 'status': 'ok'},
#  {'loss': -0.873, 'status': 'ok'},
#  {'loss': -0.8880000000000001, 'status': 'ok'},
#  {'loss': -0.8865000000000001, 'status': 'ok'},
#  {'loss': -0.8875, 'status': 'ok'},
#  {'loss': -0.8869999999999999, 'status': 'ok'},
#  {'loss': -0.8915, 'status': 'ok'},
#  {'loss': -0.8780000000000001, 'status': 'ok'},
#  {'loss': -0.8885000000000002, 'status': 'ok'},
#  {'loss': -0.8825, 'status': 'ok'},
#  {'loss': -0.8785000000000001, 'status': 'ok'},
#  {'loss': -0.8614999999999998, 'status': 'ok'},
#  {'loss': -0.8795, 'status': 'ok'},
#  {'loss': -0.8755, 'status': 'ok'},
#  {'loss': -0.8835, 'status': 'ok'},
#  {'loss': -0.867, 'status': 'ok'},
#  {'loss': -0.8800000000000001, 'status': 'ok'},
#  {'loss': -0.8819999999999999, 'status': 'ok'},
#  {'loss': -0.8779999999999999, 'status': 'ok'},
#  {'loss': -0.885, 'status': 'ok'},
#  {'loss': -0.853, 'status': 'ok'},
#  {'loss': -0.8799999999999999, 'status': 'ok'},
#  {'loss': -0.8100000000000002, 'status': 'ok'},
#  {'loss': -0.8379999999999999, 'status': 'ok'},
#  {'loss': -0.8879999999999999, 'status': 'ok'},
#  {'loss': -0.8695, 'status': 'ok'},
#  {'loss': -0.8870000000000001, 'status': 'ok'},
#  {'loss': -0.8815, 'status': 'ok'},
#  {'loss': -0.8855000000000001, 'status': 'ok'},
#  {'loss': -0.8795, 'status': 'ok'},
#  {'loss': -0.5504999999999999, 'status': 'ok'},
#  {'loss': -0.8860000000000001, 'status': 'ok'},
#  {'loss': -0.7849999999999999, 'status': 'ok'},
#  {'loss': -0.8844999999999998, 'status': 'ok'},
#  {'loss': -0.8610000000000001, 'status': 'ok'},
#  {'loss': -0.8865000000000001, 'status': 'ok'},
#  {'loss': -0.8880000000000001, 'status': 'ok'},
#  {'loss': -0.883, 'status': 'ok'},
#  {'loss': -0.8780000000000001, 'status': 'ok'},
#  {'loss': -0.8815, 'status': 'ok'},
#  {'loss': -0.8825, 'status': 'ok'},
#  {'loss': -0.8854999999999998, 'status': 'ok'},
#  {'loss': -0.8725000000000002, 'status': 'ok'},
#  {'loss': -0.8485000000000001, 'status': 'ok'},
#  {'loss': -0.882, 'status': 'ok'},
#  {'loss': -0.882, 'status': 'ok'},
#  {'loss': -0.8779999999999999, 'status': 'ok'},
#  {'loss': -0.885, 'status': 'ok'},
#  {'loss': -0.693, 'status': 'ok'},
#  {'loss': -0.8654999999999999, 'status': 'ok'},
#  {'loss': -0.8785000000000001, 'status': 'ok'},
#  {'loss': -0.8870000000000001, 'status': 'ok'},
#  {'loss': -0.8865000000000001, 'status': 'ok'},
#  {'loss': -0.8775000000000001, 'status': 'ok'},
#  {'loss': -0.8744999999999999, 'status': 'ok'},
#  {'loss': -0.8835, 'status': 'ok'},
#  {'loss': -0.8665, 'status': 'ok'},
#  {'loss': -0.882, 'status': 'ok'},
#  {'loss': -0.885, 'status': 'ok'},
#  {'loss': -0.883, 'status': 'ok'},
#  {'loss': -0.8800000000000001, 'status': 'ok'},
#  {'loss': -0.8785000000000001, 'status': 'ok'},
#  {'loss': -0.8789999999999999, 'status': 'ok'},
#  {'loss': -0.8845000000000001, 'status': 'ok'},
#  {'loss': -0.8225, 'status': 'ok'},
#  {'loss': -0.8859999999999999, 'status': 'ok'},
#  {'loss': -0.8800000000000001, 'status': 'ok'},
#  {'loss': -0.845, 'status': 'ok'},
#  {'loss': -0.8045, 'status': 'ok'},
#  {'loss': -0.8549999999999999, 'status': 'ok'},
#  {'loss': -0.8800000000000001, 'status': 'ok'}]

# %%
#  A list of losses (float for each 'ok' trial)
trials.losses()
# Out:
# [-0.8790000000000001,
#  -0.877,
#  -0.768,
#  -0.8205,
#  -0.8720000000000001,
#  -0.883,
#  -0.8554999999999999,
#  -0.8789999999999999,
#  -0.595,
#  -0.8765000000000001,
#  -0.877,
#  -0.8775000000000001,
#  -0.776,
#  -0.882,
#  -0.8744999999999999,
#  -0.825,
#  -0.757,
#  -0.8765000000000001,
#  -0.674,
#  -0.843,
#  -0.8579999999999999,
#  -0.876,
#  -0.866,
#  -0.881,
#  -0.8825,
#  -0.8879999999999999,
#  -0.8895,
#  -0.8875,
#  -0.8805,
#  -0.8855000000000001,
#  -0.873,
#  -0.8880000000000001,
#  -0.8865000000000001,
#  -0.8875,
#  -0.8869999999999999,
#  -0.8915,
#  -0.8780000000000001,
#  -0.8885000000000002,
#  -0.8825,
#  -0.8785000000000001,
#  -0.8614999999999998,
#  -0.8795,
#  -0.8755,
#  -0.8835,
#  -0.867,
#  -0.8800000000000001,
#  -0.8819999999999999,
#  -0.8779999999999999,
#  -0.885,
#  -0.853,
#  -0.8799999999999999,
#  -0.8100000000000002,
#  -0.8379999999999999,
#  -0.8879999999999999,
#  -0.8695,
#  -0.8870000000000001,
#  -0.8815,
#  -0.8855000000000001,
#  -0.8795,
#  -0.5504999999999999,
#  -0.8860000000000001,
#  -0.7849999999999999,
#  -0.8844999999999998,
#  -0.8610000000000001,
#  -0.8865000000000001,
#  -0.8880000000000001,
#  -0.883,
#  -0.8780000000000001,
#  -0.8815,
#  -0.8825,
#  -0.8854999999999998,
#  -0.8725000000000002,
#  -0.8485000000000001,
#  -0.882,
#  -0.882,
#  -0.8779999999999999,
#  -0.885,
#  -0.693,
#  -0.8654999999999999,
#  -0.8785000000000001,
#  -0.8870000000000001,
#  -0.8865000000000001,
#  -0.8775000000000001,
#  -0.8744999999999999,
#  -0.8835,
#  -0.8665,
#  -0.882,
#  -0.885,
#  -0.883,
#  -0.8800000000000001,
#  -0.8785000000000001,
#  -0.8789999999999999,
#  -0.8845000000000001,
#  -0.8225,
#  -0.8859999999999999,
#  -0.8800000000000001,
#  -0.845,
#  -0.8045,
#  -0.8549999999999999,
#  -0.8800000000000001]

# %%
# A list of status strings
trials.statuses()
# Out:
# ['ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok',
#  'ok']
